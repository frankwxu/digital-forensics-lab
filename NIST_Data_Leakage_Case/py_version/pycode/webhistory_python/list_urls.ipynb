# %%
import pandas as pd

# Set Pandas display options
pd.set_option('display.max_colwidth', 100)  # Disable column width truncation
pd.set_option('display.max_rows', None)     # Display all rows

# Read the CSV file into a DataFrame
df = pd.read_csv('IE11_container14.csv', delimiter='\t')

# Specify the columns you want to display
selected_columns = [ 'Url', 'AccessedTime', 'AccessCount']

# Create a new DataFrame containing only the selected columns
df[selected_columns].sort_values(by=['AccessCount'],ascending=[False])
# Out:
#                                                                                                     Url  \
# 28                      https://odc.officeapps.live.com/odc/jsonstrings?b=3914.1000&g=EmailHrd&mkt=1033
# 19                         https://odc.officeapps.live.com/odc/stat/images/OrgIdAccount.png?b=3914.1000
# 32                            https://odc.officeapps.live.com/odc/stat/CommonDiagnostics.js?b=3914.1000
# 31                                    https://odc.officeapps.live.com/odc/stat/EmailHrd.css?b=3914.1000
# 30                                       https://odc.officeapps.live.com/odc/stat/jquery.js?b=3914.1000
# 26                                https://odc.officeapps.live.com/odc/stat/MicrosoftAjax.js?b=3914.1000
# 25                                    https://odc.officeapps.live.com/odc/stat/Telemetry.js?b=3914.1000
# 23                            https://odc.officeapps.live.com/odc/stat/images/MSAccount.png?b=3914.1000
# ...
